# %%
import sys
sys.path.append('../')
from packages.hpo import bo_tpe, pso, smac
from packages.train import train_baseline, train_optimize
from packages.utils import create_report, read_mapped_dataset

# %% [markdown]
# Read datasets
# - QC dataset for training
# - MLCQ dataset for testing/predicting

# %%
train_data = read_mapped_dataset('QC')
test_data = read_mapped_dataset('MLCQ')
# Out:
# Loading Mapped QC dataset . . .
# Done all mapped QC datasets are loaded !
# Loading Mapped MLCQ dataset . . .
# Done all mapped MLCQ datasets are loaded !

# %%
print(f'== QC info === \n{train_data.keys()}\n-------------')
for smell in train_data:
    print(smell, "shape:",train_data[smell].shape)
    print(f'\n{train_data[smell]["is_smell"].value_counts()}\n-------------')
# Out:
# == QC info ===
# dict_keys(['Data_Class', 'Feature_Envy', 'God_Class', 'Long_Method'])
# -------------
# Data_Class shape: (420, 7)
#
# False    280
# True     140
# Name: is_smell, dtype: int64
# -------------
# Feature_Envy shape: (420, 4)
#
# False    280
# True     140
# Name: is_smell, dtype: int64
# -------------
# God_Class shape: (420, 7)
#
# False    280
# True     140
# Name: is_smell, dtype: int64
# -------------
# Long_Method shape: (420, 4)
#
# False    280
# True     140
# Name: is_smell, dtype: int64
# -------------

# %%
print(f'\n=== MLCQ info === \n {test_data.keys()}')
for smell in test_data:
    print(smell, "shape: ", test_data[smell].shape)
    print(f'\n{test_data[smell]["is_smell"].value_counts()}\n-------------')
# Out:
# === MLCQ info ===
#  dict_keys(['Data_Class', 'Feature_Envy', 'God_Class', 'Long_Method'])
# Data_Class shape:  (2154, 7)
#
# False    1870
# True      284
# Name: is_smell, dtype: int64
# -------------
# Feature_Envy shape:  (2035, 4)
#
# False    1971
# True       64
# Name: is_smell, dtype: int64
# -------------
# God_Class shape:  (2122, 7)
#
# False    1889
# True      233
# Name: is_smell, dtype: int64
# -------------
# Long_Method shape:  (2080, 4)
#
# False    1834
# True      246
# Name: is_smell, dtype: int64
# -------------

# %% [markdown]
# Experiment setup

# %%
num_folds = 10
n_repeats = 10
max_evals = 10
iters = 10

# %%
for i in range(iters):
    
    model_dir = "/transfer/{}".format(i)

    baseline_models = {}
    bo_models = {}
    pso_models = {}
    smac_models = {}

    bo_best = {}
    pso_best = {}
    smac_best = {}

    bo_compute_time = {}
    pso_compute_time = {}
    smac_compute_time = {}

    for smell in train_data:
        X_train = train_data[smell].drop(['is_smell'], axis=1)
        y_train = train_data[smell]['is_smell']

        X_test = test_data[smell].drop(['is_smell'], axis=1)
        y_test = test_data[smell]['is_smell']

        print("-------------------------- Code smell : {} --------------------------".format(smell))

        # create baseline
        baseline_models[smell] = train_baseline(X_train, y_train, smell=smell, n_splits=num_folds, n_repeats=n_repeats, model_dir=model_dir)
        
        # optimize
        bo_best[smell], bo_compute_time[smell] = bo_tpe(X_train, y_train, max_evals=max_evals)
        pso_best[smell], pso_compute_time[smell] = pso(X_train, y_train, max_evals=max_evals)
        smac_best[smell], smac_compute_time[smell] = smac(X_train, y_train, max_evals=max_evals)
        
        # crete optimized models
        bo_models[smell] = train_optimize(X_train, y_train, conf=bo_best[smell], smell=smell, hpo="bo", n_splits=num_folds, n_repeats=n_repeats, model_dir=model_dir)
        pso_models[smell] = train_optimize(X_train, y_train, conf=pso_best[smell], smell=smell, hpo="pso", n_splits=num_folds, n_repeats=n_repeats, model_dir=model_dir)
        smac_models[smell] = train_optimize(X_train, y_train, conf=smac_best[smell], smell=smell, hpo="smac", n_splits=num_folds, n_repeats=n_repeats, model_dir=model_dir)

        
        #  predict =
        for model in range(2):
            baseline_models[smell][model].set_prediction_score(X_test, y_test)
            bo_models[smell][model].set_prediction_score(X_test, y_test)
            pso_models[smell][model].set_prediction_score(X_test, y_test)
            smac_models[smell][model].set_prediction_score(X_test, y_test)
    
    create_report(baseline_models, report_name="/transfer/baseline_{}.csv".format(i))
    create_report(bo_models, bo_compute_time, report_name="/transfer/bo_{}.csv".format(i))
    create_report(pso_models, pso_compute_time, report_name="/transfer/pso_{}.csv".format(i))
    create_report(smac_models, smac_compute_time, report_name="/transfer/smac_{}.csv".format(i))
# Out:
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 33.12trial/s, best loss: -0.8357142857142857]
# 100%|██████████| 10/10 [00:06<00:00,  1.63trial/s, best loss: -0.8857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.26trial/s, best loss: -0.65]
# 100%|██████████| 10/10 [00:04<00:00,  2.04trial/s, best loss: -0.7785714285714286]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 32.23trial/s, best loss: -0.95]
# 100%|██████████| 10/10 [00:05<00:00,  1.97trial/s, best loss: -0.9642857142857142]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 31.04trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.29trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_0.csv
# Report exported ! at /transfer/bo_0.csv
# Report exported ! at /transfer/pso_0.csv
# Report exported ! at /transfer/smac_0.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 32.90trial/s, best loss: -0.8571428571428571]
# 100%|██████████| 10/10 [00:05<00:00,  1.97trial/s, best loss: -0.8857142857142856]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 30.30trial/s, best loss: -0.7]
# 100%|██████████| 10/10 [00:04<00:00,  2.14trial/s, best loss: -0.7714285714285714]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.35trial/s, best loss: -0.95]
# 100%|██████████| 10/10 [00:05<00:00,  1.88trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 31.92trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.30trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_1.csv
# Report exported ! at /transfer/bo_1.csv
# Report exported ! at /transfer/pso_1.csv
# Report exported ! at /transfer/smac_1.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.60trial/s, best loss: -0.8714285714285713]
# 100%|██████████| 10/10 [00:04<00:00,  2.25trial/s, best loss: -0.8785714285714284]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 34.33trial/s, best loss: -0.6714285714285715]
# 100%|██████████| 10/10 [00:04<00:00,  2.20trial/s, best loss: -0.7785714285714286]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 33.19trial/s, best loss: -0.9428571428571428]
# 100%|██████████| 10/10 [00:04<00:00,  2.15trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 29.47trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.21trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_2.csv
# Report exported ! at /transfer/bo_2.csv
# Report exported ! at /transfer/pso_2.csv
# Report exported ! at /transfer/smac_2.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.37trial/s, best loss: -0.8642857142857142]
# 100%|██████████| 10/10 [00:05<00:00,  1.82trial/s, best loss: -0.8857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 34.72trial/s, best loss: -0.7571428571428571]
# 100%|██████████| 10/10 [00:05<00:00,  1.82trial/s, best loss: -0.7928571428571428]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.81trial/s, best loss: -0.9642857142857142]
# 100%|██████████| 10/10 [00:04<00:00,  2.11trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 26.35trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.49trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_3.csv
# Report exported ! at /transfer/bo_3.csv
# Report exported ! at /transfer/pso_3.csv
# Report exported ! at /transfer/smac_3.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 29.05trial/s, best loss: -0.8714285714285716]
# 100%|██████████| 10/10 [00:04<00:00,  2.01trial/s, best loss: -0.8857142857142856]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 30.12trial/s, best loss: -0.7642857142857142]
# 100%|██████████| 10/10 [00:04<00:00,  2.17trial/s, best loss: -0.7785714285714286]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 29.61trial/s, best loss: -0.9571428571428573]
# 100%|██████████| 10/10 [00:04<00:00,  2.36trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 31.35trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.05trial/s, best loss: -0.9928571428571429]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_4.csv
# Report exported ! at /transfer/bo_4.csv
# Report exported ! at /transfer/pso_4.csv
# Report exported ! at /transfer/smac_4.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.26trial/s, best loss: -0.8571428571428571]
# 100%|██████████| 10/10 [00:04<00:00,  2.12trial/s, best loss: -0.8785714285714287]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.88trial/s, best loss: -0.6642857142857144]
# 100%|██████████| 10/10 [00:05<00:00,  1.89trial/s, best loss: -0.8071428571428572]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 33.55trial/s, best loss: -0.9428571428571428]
# 100%|██████████| 10/10 [00:05<00:00,  1.95trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 25.05trial/s, best loss: -0.9857142857142858]
# 100%|██████████| 10/10 [00:05<00:00,  1.94trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_5.csv
# Report exported ! at /transfer/bo_5.csv
# Report exported ! at /transfer/pso_5.csv
# Report exported ! at /transfer/smac_5.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 26.86trial/s, best loss: -0.85]
# 100%|██████████| 10/10 [00:05<00:00,  1.80trial/s, best loss: -0.8785714285714284]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 32.36trial/s, best loss: -0.6785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.01trial/s, best loss: -0.8071428571428572]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 25.38trial/s, best loss: -0.9642857142857142]
# 100%|██████████| 10/10 [00:04<00:00,  2.41trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.41trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.21trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_6.csv
# Report exported ! at /transfer/bo_6.csv
# Report exported ! at /transfer/pso_6.csv
# Report exported ! at /transfer/smac_6.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 30.94trial/s, best loss: -0.8285714285714286]
# 100%|██████████| 10/10 [00:05<00:00,  1.96trial/s, best loss: -0.8857142857142856]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 30.33trial/s, best loss: -0.6785714285714286]
# 100%|██████████| 10/10 [00:05<00:00,  1.90trial/s, best loss: -0.7642857142857142]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 30.94trial/s, best loss: -0.9642857142857142]
# 100%|██████████| 10/10 [00:05<00:00,  1.85trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 28.42trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.11trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_7.csv
# Report exported ! at /transfer/bo_7.csv
# Report exported ! at /transfer/pso_7.csv
# Report exported ! at /transfer/smac_7.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 29.07trial/s, best loss: -0.85]
# 100%|██████████| 10/10 [00:05<00:00,  1.83trial/s, best loss: -0.8857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 32.90trial/s, best loss: -0.7]
# 100%|██████████| 10/10 [00:04<00:00,  2.39trial/s, best loss: -0.7642857142857142]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 26.46trial/s, best loss: -0.95]
# 100%|██████████| 10/10 [00:04<00:00,  2.15trial/s, best loss: -0.9642857142857142]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.12trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:05<00:00,  1.93trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_8.csv
# Report exported ! at /transfer/bo_8.csv
# Report exported ! at /transfer/pso_8.csv
# Report exported ! at /transfer/smac_8.csv
# -------------------------- Code smell : Data_Class --------------------------
# creating baseline . . .
# Model: /baseline_Data_Class_decision_tree.pkl exported !
# Model: /baseline_Data_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.45trial/s, best loss: -0.8642857142857142]
# 100%|██████████| 10/10 [00:05<00:00,  1.96trial/s, best loss: -0.8785714285714284]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Data_Class_decision_tree.pkl exported !
# Model: /bo_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Data_Class_decision_tree.pkl exported !
# Model: /pso_Data_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Data_Class_decision_tree.pkl exported !
# Model: /smac_Data_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Feature_Envy --------------------------
# creating baseline . . .
# Model: /baseline_Feature_Envy_decision_tree.pkl exported !
# Model: /baseline_Feature_Envy_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 27.54trial/s, best loss: -0.65]
# 100%|██████████| 10/10 [00:04<00:00,  2.18trial/s, best loss: -0.7642857142857142]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Feature_Envy_decision_tree.pkl exported !
# Model: /bo_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Feature_Envy_decision_tree.pkl exported !
# Model: /pso_Feature_Envy_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Feature_Envy_decision_tree.pkl exported !
# Model: /smac_Feature_Envy_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : God_Class --------------------------
# creating baseline . . .
# Model: /baseline_God_Class_decision_tree.pkl exported !
# Model: /baseline_God_Class_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 29.85trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.13trial/s, best loss: -0.9714285714285713]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_God_Class_decision_tree.pkl exported !
# Model: /bo_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_God_Class_decision_tree.pkl exported !
# Model: /pso_God_Class_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_God_Class_decision_tree.pkl exported !
# Model: /smac_God_Class_random_forest.pkl exported !
# Done !
# -------------------------- Code smell : Long_Method --------------------------
# creating baseline . . .
# Model: /baseline_Long_Method_decision_tree.pkl exported !
# Model: /baseline_Long_Method_random_forest.pkl exported !
# Done !
# 100%|██████████| 10/10 [00:00<00:00, 31.06trial/s, best loss: -0.9785714285714286]
# 100%|██████████| 10/10 [00:04<00:00,  2.39trial/s, best loss: -0.9857142857142858]
# Done !
#
# Optmize using PSO . . .  Done !
#
# Optmize using SMAC . . .  Done !
# creating model using hyper-params from BO . . .
# Model: /bo_Long_Method_decision_tree.pkl exported !
# Model: /bo_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from PSO . . .
# Model: /pso_Long_Method_decision_tree.pkl exported !
# Model: /pso_Long_Method_random_forest.pkl exported !
# Done !
# creating model using hyper-params from SMAC . . .
# Model: /smac_Long_Method_decision_tree.pkl exported !
# Model: /smac_Long_Method_random_forest.pkl exported !
# Done !
# Report exported ! at /transfer/baseline_9.csv
# Report exported ! at /transfer/bo_9.csv
# Report exported ! at /transfer/pso_9.csv
# Report exported ! at /transfer/smac_9.csv
